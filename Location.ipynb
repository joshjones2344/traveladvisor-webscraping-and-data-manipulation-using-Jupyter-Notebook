# %%
import pandas as pd
import os

# Load the data from CSV files
hotel_df = pd.read_csv(r'C:\Users\Admin\Downloads\SPARTA\SP702 CAPSTONE\FINAL_OUTPUT\Hotel.csv')
restaurant_df = pd.read_csv(r'C:\Users\Admin\Downloads\SPARTA\SP702 CAPSTONE\FINAL_OUTPUT\Restaurant.csv')
tourist_sites_df = pd.read_csv(r'C:\Users\Admin\Downloads\SPARTA\SP702 CAPSTONE\FINAL_OUTPUT\Tourist_site.csv')

# Merge the data into a single DataFrame
merged_df = pd.concat([hotel_df, restaurant_df, tourist_sites_df], ignore_index=True)

# Filter rows where 'address' contains "Cebu"
cebu_data = merged_df[merged_df['address'].str.contains('Cebu', case=False)]

# Save the filtered data to a CSV file
cebu_data.to_csv(r'C:\Users\Admin\Downloads\SPARTA\SP702 CAPSTONE\FINAL_OUTPUT\Location.csv', index=False)
cebu_data
# Out:
#                                    hotelname  \
# 0                        Eloisa Royal Suites
# 1                       Mandarin Plaza Hotel
# 4                            Red Planet Cebu
# 8    Bayfront Hotel Cebu - North Reclamation
# 10                      Summit Galleria Cebu
# 12       Waterfront Cebu City Hotel & Casino
# 17                         Radisson Blu Cebu
# 19                    Seda Central Bloc Cebu
# 22                    Seda Ayala Center Cebu
# 24                           Fili Hotel Cebu
# 25            Dusit Thani Mactan Cebu Resort
# 26  Quest Hotel and Conference Center - Cebu
# 27                            Harolds Evotel
# 34                                       NaN
# 36                                       NaN
# 39                                       NaN
# 44                                       NaN
# 46                                       NaN
# 49                                       NaN
# 51                                       NaN
# ...
