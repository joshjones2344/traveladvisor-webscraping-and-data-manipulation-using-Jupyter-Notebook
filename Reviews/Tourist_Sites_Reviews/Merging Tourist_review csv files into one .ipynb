# %% [markdown]
# i want to merge all reviews each tourist sites with 15 attributes and more using this code
# also i used data scaper extension each hotel review and merge it into one cell using Textjoin clause
# excel.

# %%
import pandas as pd
import glob
from tqdm import tqdm
# Create an empty DataFrame to store the combined data
combined_df = pd.DataFrame(columns=['touristname', 'reviews'])

# List all CSV files in the current directory
csv_files = glob.glob('*.csv')

# Loop through each CSV file and concatenate them
for csv_file in csv_files:
    df = pd.read_csv(csv_file)
    combined_df = pd.concat([combined_df, df])
tqdm.pandas()
# Reset the index of the combined DataFrame
combined_df.reset_index(drop=True, inplace=True)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv(r'C:\Users\Admin\Downloads\SPARTA\SP702 CAPSTONE\Reviews\Tourist_Sites_Reviews.csv', index=False)

# %%
combined_df
# Out:
#                         touristname  \
# 0                 1730 Jesuit House
# 1                     Aguinid Falls
# 2                 Ayala Center Cebu
# 3           Basilica del Santo Nino
# 4               Casa Gorordo Museum
# 5            Cebu Heritage Monument
# 6       Cebu Metropolitan Cathedral
# 7                   Cebu Ocean Park
# 8                      Colon Street
# 9                    Fort San Pedro
# 10      Jumalon Butterfly Sanctuary
# 11                    Kawasan Falls
# 12                 Lapu Lapu Statue
# 13                      Museo Sugbo
# 14                      Osmena Peak
# 15                   Paradise Beach
# 16                  Pescador Island
# 17                    Simala Shrine
# 18              Sirao Flower Garden
# 19             SM Seaside City Cebu
# 20                   Sumilon Island
# 21                    Taoist Temple
# 22                   Temple of Leah
# 23                     Tops Lookout
# 24                    Tumalog Falls
# ...

# %% [markdown]
# ##now we can able to merge it to final tourist sites data
